# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("/content/Data null.csv")

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title    salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000.0             EUR        79833.0
# 1    Machine Learning Scientist  260000.0             USD       260000.0
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000.0             EUR        79833.0
# 1  Machine Learning Scientist  260000.0             USD       260000.0
# 2           Big Data Engineer   85000.0             GBP       109024.0
# 3        Product Data Analyst   20000.0             USD        20000.0
# 4   Machine Learning Engineer  150000.0             USD       150000.0
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000.0             USD       154000.0                 US           100
# 603  126000.0             USD       126000.0                 US           100
# 604  129000.0             USD       129000.0                 US             0
# 605  150000.0             USD       150000.0                 US           100
# 606  200000.0             USD       200000.0                 IN           100
#
#     company_location company_size
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title      salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000.0             EUR        79833.0
# 1  Machine Learning Scientist    260000.0             USD       260000.0
# 2           Big Data Engineer     85000.0             GBP       109024.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.301795e+05  111771.647446      70.92257
# std    175.370085     0.692133  1.543854e+06   70717.745100      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.025000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.160000e+05  100000.000000     100.00000
# 75%    454.500000  2022.000000  1.700000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# work_year               int64
# experience_level       object
# employment_type        object
# job_title              object
# salary                float64
# salary_currency        object
# salary_in_usd         float64
# employee_residence     object
# remote_ratio            int64
# company_location       object
# company_size           object
# dtype: object

# %%
df.nunique()
# Out:
# Unnamed: 0            607
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                269
# salary_currency        17
# salary_in_usd         365
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    float64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    float64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 57.0+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# work_year              0
# experience_level       0
# employment_type        0
# job_title              0
# salary                18
# salary_currency        0
# salary_in_usd          6
# employee_residence     0
# remote_ratio           0
# company_location       0
# company_size           0
# dtype: int64

# %%
mean = df["salary"].mean()
mean
# Out:
# 330179.52122241084

# %%
def fill_NAN_salary_mean(df,variable,mean):
  df[variable]=df[variable].fillna(mean)
fill_NAN_salary_mean(df,"salary",mean)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         6
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
median = df["salary_in_usd"].median()
median
# Out:
# 100000.0

# %%
def fill_NAN_salary_in_usd_median(df,variable,median):
  df[variable]=df[variable].fillna(median)
fill_NAN_salary_in_usd_median(df,"salary_in_usd",median)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title    salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000.0             EUR        79833.0
# 1    Machine Learning Scientist  260000.0             USD       260000.0
# ...

# %%
df["work_year"].value_counts()
# Out:
# 2022    318
# 2021    217
# 2020     72
# Name: work_year, dtype: int64

# %%
df['experience_level'].value_counts()
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
g = sns.histplot(df['salary_in_usd'])
g.set(xlabel = 'Salary (USD)', ylabel = '', title = 'Histogram of salary (USD)')
g

# %%
print("The highest salary is :", df['salary_in_usd'].max())
print("The lowest salary is :", df['salary_in_usd'].min())
# Out:
# The highest salary is : 600000.0
# The lowest salary is : 2859.0

# %%
def pay(x):
    if x < 45000:
        return '<45K'
    elif x < 80000:
        return '<80K'
    elif x < 200000:
        return '<200K'
    else:
        return '>200K'
pay_index = [['<45', '<80k', '<200k', '>200k']]
df['pay'] = df['salary_in_usd'].apply(pay)
pay_percent = df['pay'].value_counts(normalize = True).mul(100).round(1).astype(str)+'%'
pay_percent
# Out:
# <200K    54.2%
# <80K     21.4%
# <45K     14.0%
# >200K    10.4%
# Name: pay, dtype: object

# %%
df_c = df.corr()
one_like = np.ones_like(df_c, dtype = bool)
mask1 = np.triu(one_like)
print(df_c)

sns.heatmap(df_c, annot = True, fmt = ".2f", cmap = 'Greens')
# Out:
#                Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# Unnamed: 0       1.000000   0.886550 -0.096662       0.157186      0.095000
# work_year        0.886550   1.000000 -0.088417       0.164666      0.076314
# salary          -0.096662  -0.088417  1.000000      -0.085110     -0.013837
# salary_in_usd    0.157186   0.164666 -0.085110       1.000000      0.126865
# remote_ratio     0.095000   0.076314 -0.013837       0.126865      1.000000

# %%
fig = plt.figure(figsize = (20,10))
plt.bar(df ["job_title"],df ["salary"],color = "Red",width = 0.7)
plt.xlabel("Job Title")
plt.ylabel("Salary in Rs.")
plt.title("Jobs & their Salary's")
plt.show()
